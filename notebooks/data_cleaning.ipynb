# %%
pip install  nltk
# Out:
# ...
#   Using cached nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached regex-2024.11.6-cp310-cp310-win_amd64.whl.metadata (41 kB)
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# ...
# Using cached nltk-3.9.1-py3-none-any.whl (1.5 MB)
# Using cached regex-2024.11.6-cp310-cp310-win_amd64.whl (274 kB)
# ...
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# ...
#
#    -------- ------------------------------- 1/5 [regex]
#    ---------------- ----------------------- 2/5 [joblib]
#    ---------------- ----------------------- 2/5 [joblib]
#    ---------------- ----------------------- 2/5 [joblib]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
# ...

# %%
import re
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import nltk

# %%
import re
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import nltk

# Download required NLTK data (only once)
nltk.download('punkt')
nltk.download('stopwords')

stop_words = set(stopwords.words('english'))

def clean_and_tokenize(text):
    """
    Clean text by lowercasing, removing punctuation/numbers,
    and returning list of cleaned tokens (no stopwords).
    """
    text = text.lower()
    text = re.sub(r'\d+', '', text)
    text = text.translate(str.maketrans('', '', string.punctuation))
    tokens = word_tokenize(text)
    tokens = [word for word in tokens if word not in stop_words and len(word) > 2]
    return tokens
# Out:
# [nltk_data] Downloading package punkt to C:\Users\sandesh
# [nltk_data]     badiger\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\sandesh
# [nltk_data]     badiger\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
pip install scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/10.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.7 MB ? eta -:--:--
#    - -------------------------------------- 0.5/10.7 MB 5.6 MB/s eta 0:00:02
#    --- ------------------------------------ 1.0/10.7 MB 2.5 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.6/10.7 MB 2.4 MB/s eta 0:00:04
#    ------- -------------------------------- 2.1/10.7 MB 2.4 MB/s eta 0:00:04
#    --------- ------------------------------ 2.6/10.7 MB 2.4 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.1/10.7 MB 2.4 MB/s eta 0:00:04
#    ------------ --------------------------- 3.4/10.7 MB 2.4 MB/s eta 0:00:04
#    -------------- ------------------------- 3.9/10.7 MB 2.4 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.5/10.7 MB 2.3 MB/s eta 0:00:03
#    -------------------- ------------------- 5.5/10.7 MB 2.6 MB/s eta 0:00:03
# ...

# %%
pip install gensim
# Out:
# ...
#   Using cached smart_open-7.1.0-py3-none-any.whl.metadata (24 kB)
# ...
#    ---------------------------------------- 0.0/24.0 MB ? eta -:--:--
#    ----- ---------------------------------- 3.1/24.0 MB 30.7 MB/s eta 0:00:01
#    ----- ---------------------------------- 3.4/24.0 MB 9.6 MB/s eta 0:00:03
#    -------- ------------------------------- 5.2/24.0 MB 9.1 MB/s eta 0:00:03
#    ---------- ----------------------------- 6.0/24.0 MB 7.7 MB/s eta 0:00:03
#    ---------- ----------------------------- 6.3/24.0 MB 6.2 MB/s eta 0:00:03
#    ---------- ----------------------------- 6.6/24.0 MB 5.7 MB/s eta 0:00:04
#    ------------ --------------------------- 7.3/24.0 MB 5.1 MB/s eta 0:00:04
#    ------------- -------------------------- 7.9/24.0 MB 4.8 MB/s eta 0:00:04
#    ------------- -------------------------- 8.1/24.0 MB 4.5 MB/s eta 0:00:04
#    ------------- -------------------------- 8.4/24.0 MB 4.3 MB/s eta 0:00:04
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
import pandas as pd
import re
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import nltk

# Setup
nltk.download('punkt')
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package punkt to C:\Users\sandesh
# [nltk_data]     badiger\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\sandesh
# [nltk_data]     badiger\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# from notebooks.data_cleaning import clean_and_tokenize
# notebooks\data_cleaning.ipynb
import pandas as pd
import numpy as np
import re
import string
import joblib

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import nltk

nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\sandesh
# [nltk_data]     badiger\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\sandesh
# [nltk_data]     badiger\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import nltk

# Download these once (won't re-download every time)
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\sandesh
# [nltk_data]     badiger\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\sandesh
# [nltk_data]     badiger\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\sandesh
# [nltk_data]     badiger\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\sandesh
# [nltk_data]     badiger\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import pandas as pd
import re
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import nltk

# Setup
nltk.download('punkt')
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

# Load raw data
df = pd.read_csv("C:\\Users\\sandesh badiger\\Desktop\\Documents\\smart-email-assistant\\data\\synthetic_emails.csv")

# Cleaning function
from nltk.tokenize import word_tokenize

def clean_and_tokenize(text):
    text = text.lower()
    text = re.sub(r'\d+', '', text)  # Remove numbers (optional, keep if needed)
    tokens = word_tokenize(text)    # Keeps punctuation as separate tokens
    # No stopword removal here
    tokens = [word for word in tokens if len(word) > 2]
    return tokens

# Apply cleaning
df['tokens'] = df['email_text'].apply(clean_and_tokenize)

# Save cleaned dataset
df.to_csv('data/cleaned_emails.csv', index=False)
print("✅ Cleaned data saved to data/cleaned_emails.csv")
# Out:
# [nltk_data] Downloading package punkt to C:\Users\sandesh
# [nltk_data]     badiger\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\sandesh
# [nltk_data]     badiger\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[16], line 28
#      25     return tokens
#      27 # Apply cleaning
# ---> 28 df['tokens'] = df['email_text'].apply(clean_and_tokenize)
#      30 # Save cleaned dataset
#      31 df.to_csv('data/cleaned_emails.csv', index=False)
#
# File c:\Users\sandesh badiger\anaconda3\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
# ...
